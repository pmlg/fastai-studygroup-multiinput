# %% [markdown]
# # Setup Colab

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !wget https://launchpad.net/~alessandro-strada/+archive/ubuntu/google-drive-ocamlfuse-beta/+build/15331130/+files/google-drive-ocamlfuse_0.7.0-0ubuntu1_amd64.deb
# !dpkg -i google-drive-ocamlfuse_0.7.0-0ubuntu1_amd64.deb
# !apt-get install -f
# !apt-get -y install -qq fuse

# %%
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# !mkdir -p drive
# !google-drive-ocamlfuse drive -o nonempty
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8.1_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8.1) ...
# Selecting previously unselected package distro-info-data.
# Preparing to unpack .../05-distro-info-data_0.36ubuntu0.2_all.deb ...
# Unpacking distro-info-data (0.36ubuntu0.2) ...
# Selecting previously unselected package libkmod2:amd64.
# Preparing to unpack .../06-libkmod2_24-1ubuntu2_amd64.deb ...
# Unpacking libkmod2:amd64 (24-1ubuntu2) ...
# Selecting previously unselected package kmod.
# Preparing to unpack .../07-kmod_24-1ubuntu2_amd64.deb ...
# Unpacking kmod (24-1ubuntu2) ...
# Selecting previously unselected package lsb-release.
# Preparing to unpack .../08-lsb-release_9.20160110ubuntu5_all.deb ...
# Unpacking lsb-release (9.20160110ubuntu5) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../09-libgirepository-1.0-1_1.54.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../10-gir1.2-glib-2.0_1.54.1-1_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Selecting previously unselected package iso-codes.
# Preparing to unpack .../11-iso-codes_3.75-1_all.deb ...
# Unpacking iso-codes (3.75-1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../12-libdbus-glib-1-2_0.108-2_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.108-2) ...
# Selecting previously unselected package python-apt-common.
# Preparing to unpack .../13-python-apt-common_1.4.0~beta3build2_all.deb ...
# Unpacking python-apt-common (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-apt.
# Preparing to unpack .../14-python3-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python3-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-dbus.
# Preparing to unpack .../15-python3-dbus_1.2.4-1build3_amd64.deb ...
# Unpacking python3-dbus (1.2.4-1build3) ...
# Selecting previously unselected package python3-gi.
# Preparing to unpack .../16-python3-gi_3.24.1-2build1_amd64.deb ...
# Unpacking python3-gi (3.24.1-2build1) ...
# Selecting previously unselected package module-init-tools.
# Preparing to unpack .../17-module-init-tools_24-1ubuntu2_all.deb ...
# Unpacking module-init-tools (24-1ubuntu2) ...
# Selecting previously unselected package python-apt.
# Preparing to unpack .../18-python-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python-pycurl.
# Preparing to unpack .../19-python-pycurl_7.43.0-2build2_amd64.deb ...
# Unpacking python-pycurl (7.43.0-2build2) ...
# Selecting previously unselected package python-software-properties.
# Preparing to unpack .../20-python-software-properties_0.96.24.17_all.deb ...
# Unpacking python-software-properties (0.96.24.17) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../21-python3-software-properties_0.96.24.17_all.deb ...
# Unpacking python3-software-properties (0.96.24.17) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../22-software-properties-common_0.96.24.17_all.deb ...
# Unpacking software-properties-common (0.96.24.17) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../23-unattended-upgrades_0.98ubuntu1.1_all.deb ...
# Unpacking unattended-upgrades (0.98ubuntu1.1) ...
# Setting up python-apt-common (1.4.0~beta3build2) ...
# Setting up python3-apt (1.4.0~beta3build2) ...
# Setting up iso-codes (3.75-1) ...
# Setting up distro-info-data (0.36ubuntu0.2) ...
# Setting up python-pycurl (7.43.0-2build2) ...
# Setting up lsb-release (9.20160110ubuntu5) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libkmod2:amd64 (24-1ubuntu2) ...
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up unattended-upgrades (0.98ubuntu1.1) ...
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
#
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up dirmngr (2.1.15-1ubuntu8.1) ...
# Setting up cron (3.0pl1-128ubuntu5) ...
# Adding group `crontab' (GID 102) ...
# Done.
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# update-rc.d: warning: stop runlevel arguments (1) do not match cron Default-Stop values (none)
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up kmod (24-1ubuntu2) ...
# Setting up libdbus-glib-1-2:amd64 (0.108-2) ...
# Setting up python3-gi (3.24.1-2build1) ...
# Setting up module-init-tools (24-1ubuntu2) ...
# Setting up python3-software-properties (0.96.24.17) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up python-apt (1.4.0~beta3build2) ...
# Setting up python3-dbus (1.2.4-1build3) ...
# Setting up python-software-properties (0.96.24.17) ...
# Setting up software-properties-common (0.96.24.17) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for dbus (1.10.22-1ubuntu1) ...
# gpg: keybox '/tmp/tmp3f4_5n94/pubring.gpg' created
# gpg: /tmp/tmp3f4_5n94/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 19816 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.6.21-0ubuntu2_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %% [markdown]
# #Fast.AI Setup
# !pip install get+https://github.com/fastai/fastai.git

# %%
import os
os.chdir('/content')
# !git clone https://github.com/fastai/fastai.git
# Out:
# Cloning into 'fastai'...
# remote: Counting objects: 6764, done.
# remote: Total 6764 (delta 0), reused 0 (delta 0), pack-reused 6763
# Receiving objects: 100% (6764/6764), 206.04 MiB | 41.88 MiB/s, done.
# Resolving deltas: 100% (4265/4265), done.

# %%
#Fast.AI Setup
os.chdir("fastai")
# !git pull
# Out:
# Already up-to-date.

# %%
os.chdir("..")
# !pip install https://github.com/fastai/fastai/archive/master.zip
# Out:
# Collecting https://github.com/fastai/fastai/archive/master.zip
#   Downloading https://github.com/fastai/fastai/archive/master.zip
#      - 114.9MB 97.5MB/s
# Collecting bcolz (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/5c/4e/23942de9d5c0fb16f10335fa83e52b431bcb8c0d4a8419c9ac206268c279/bcolz-1.2.1.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 8.3MB/s
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.8.24)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Collecting feather-format (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/08/55/940b97cc6f19a19f5dab9efef2f68a0ce43a7632f858b272391f0b851a7e/feather-format-0.4.0.tar.gz
# Collecting graphviz (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/47/87/313cd4ea4f75472826acb74c57f94fc83e04ba93e4ccf35656f6b7f502e2/graphviz-0.9-py2.py3-none-any.whl
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.6.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (5.5.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.0)
# Collecting ipywidgets (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/ea/c5/0482342559f0fd24909572fe00bb59b2bae98b22d90aac7950f51a98f555/ipywidgets-7.4.1-py2.py3-none-any.whl (110kB)
#     100% |████████████████████████████████| 112kB 14.4MB/s
# Collecting isoweek (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/c2/d4/fe7e2637975c476734fcbf53776e650a29680194eb0dd21dbdc020ca92de/isoweek-1.3.3-py2.py3-none-any.whl
# Collecting jedi (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/3d/68/8bbf0ef969095a13ba0d4c77c1945bd86e9811960d052510551d29a2f23b/jedi-0.12.1-py2.py3-none-any.whl (174kB)
#     100% |████████████████████████████████| 184kB 14.7MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.10)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.6.0)
# Collecting jupyter (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.14.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.3.18)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.22.0)
# Collecting pandas_summary (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/97/55/ea54109a4e7a8e7342bdf23e9382c858224263d984b0d95610568e564f59/pandas_summary-0.0.5-py2.py3-none-any.whl
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.0.0)
# Collecting plotnine (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/fe/49/7af942bc63277dfca6ad397415f4cff60789c56d173b1f7edf0bd30e27e0/plotnine-0.4.0-py2.py3-none-any.whl (3.6MB)
#     100% |████████████████████████████████| 3.6MB 8.6MB/s
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.6.0)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.2.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.13)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (16.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.19.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.1)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.8.1)
# Collecting sklearn_pandas (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/7e/9c/c94f46b40b86d2c77c46c4c1b858fc66c117b4390665eca28f2e0812db45/sklearn_pandas-1.7.0-py2.py3-none-any.whl
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.0.12)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3.1)
# Collecting torch<0.4 (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/5b/a5/e8b50b55b1abac9f1e3346c4242f1e42a82d368a8442cbd50c532922f6c4/torch-0.3.1-cp36-cp36m-manylinux1_x86_64.whl (496.4MB)
#     100% |████████████████████████████████| 496.4MB 29kB/s
# Collecting torchtext (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/78/90/474d5944d43001a6e72b9aaed5c3e4f77516fbef2317002da2096fd8b5ea/torchtext-0.2.3.tar.gz (42kB)
#     100% |████████████████████████████████| 51kB 21.5MB/s
# Collecting torchvision (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 22.7MB/s
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.25.0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.1.7)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Collecting widgetsnbextension (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/3c/9a/9a690e18e335fc4470a2fa38163774940159375798ba6cce043d5cd94bae/widgetsnbextension-3.4.1-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 804kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from bleach->fastai==0.7.0) (1.11.0)
# Collecting pyarrow>=0.4.0 (from feather-format->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/c9/b8/076ebd968f3c6d4e9b6e5de696f0b19964a3d4b7dc020fd32db4e868ad74/pyarrow-0.10.0-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 2.6MB/s
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->fastai==0.7.0) (5.2.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (39.1.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (1.0.15)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (4.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==0.7.0) (4.4.0)
# Collecting parso>=0.3.0 (from jedi->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/09/51/9c48a46334be50c13d25a3afe55fa05c445699304c5ad32619de953a2305/parso-0.3.1-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 28.8MB/s
# Collecting qtconsole (from jupyter->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/ff/1f/b340d52dee46fbbe8a097dce76d1197258bb599692159d94c80921fef9eb/qtconsole-4.4.1-py2.py3-none-any.whl (112kB)
#     100% |████████████████████████████████| 112kB 32.2MB/s
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.4.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.2.2)
# Collecting jupyter-console (from jupyter->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/77/82/6469cd7fccf7958cbe5dce2e623f1e3c5e27f1bb1ad36d90519bc2d5d370/jupyter_console-5.2.0-py2.py3-none-any.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai==0.7.0) (0.46)
# Collecting geopandas>=0.3.0 (from plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/24/11/d77c157c16909bd77557d00798b05a5b6615ed60acb5900fbe6a65d35e93/geopandas-0.4.0-py2.py3-none-any.whl (899kB)
#     100% |████████████████████████████████| 901kB 2.8MB/s
# Collecting descartes>=1.1.0 (from plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/e5/b6/1ed2eb03989ae574584664985367ba70cd9cf8b32ee8cad0e8aaeac819f3/descartes-1.1.0-py3-none-any.whl
# Collecting mizani>=0.4.5 (from plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/52/01/8a3b4c6e45749674a1e5241174b4b63cd6435125e124bec275f3e02c96ac/mizani-0.4.6-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 27.4MB/s
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.0)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_pandas->fastai==0.7.0) (0.19.2)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (0.28.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (1.0.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (6.10.3)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (0.9.6)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (1.35)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (0.2.8.2)
# Requirement already satisfied: regex==2017.4.5 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (2017.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==0.7.0) (2.18.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.2)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.3)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->fastai==0.7.0) (0.8.1)
# Collecting shapely (from geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 6.4MB/s
# Collecting pyproj (from geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/29/72/5c1888c4948a0c7b736d10e0f0f69966e7c0874a660222ed0a2c2c6daa9f/pyproj-1.9.5.1.tar.gz (4.4MB)
#     100% |████████████████████████████████| 4.4MB 3.0MB/s
# Collecting fiona (from geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/e3/bf/029958f4e3811ce7017fb5805d5203e8bde6c1816b902964acb2dec67863/Fiona-1.7.13-cp36-cp36m-manylinux1_x86_64.whl (15.8MB)
#     100% |████████████████████████████████| 15.8MB 1.7MB/s
# Collecting palettable (from mizani>=0.4.5->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/56/8a/84537c0354f0d1f03bf644b71bf8e0a50db9c1294181905721a5f3efbf66/palettable-3.1.1-py2.py3-none-any.whl (77kB)
#     100% |████████████████████████████████| 81kB 26.5MB/s
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy->fastai==0.7.0) (0.5.6)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy->fastai==0.7.0) (0.4.3.1)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy->fastai==0.7.0) (0.9.0.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy->fastai==0.7.0) (1.10.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->fastai==0.7.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->fastai==0.7.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->fastai==0.7.0) (1.22)
# Collecting cligj>=0.4 (from fiona->geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/fc/05/e8384e1f7c8689cd1b91818a24cc860077c73368fb285ba53fbd8556ec98/cligj-0.4.0-py3-none-any.whl
# Collecting munch (from fiona->geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/68/f4/260ec98ea840757a0da09e0ed8135333d59b8dfebe9752a365b04857660a/munch-2.3.2.tar.gz
# Collecting click-plugins (from fiona->geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/77/05/da5c9e19457f20cadfe22c397cd3852577066066f63e40f2baa0831b1693/click-plugins-1.0.3.tar.gz
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy->fastai==0.7.0) (0.9.0)
# Collecting click>=4.0 (from cligj>=0.4->fiona->geopandas>=0.3.0->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/34/c1/8806f99713ddb993c5366c362b2f908f18269f8d792aff1abfd700775a77/click-6.7-py2.py3-none-any.whl (71kB)
#     100% |████████████████████████████████| 71kB 23.7MB/s
# Building wheels for collected packages: fastai, bcolz, feather-format, torchtext, pyproj, munch, click-plugins
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uj8juzsk/wheels/64/3d/9f/d12a217aa2531321c5b9ae96288fcae2687d3b744376e8f94f
# done
#   Stored in directory: /root/.cache/pip/wheels/9f/78/26/fb8c0acb91a100dc8914bf236c4eaa4b207cb876893c40b745
# done
#   Stored in directory: /root/.cache/pip/wheels/85/7d/12/2dfa5c0195f921ac935f5e8f27deada74972edc0ae9988a9c1
# done
#   Stored in directory: /root/.cache/pip/wheels/42/a6/f4/b267328bde6bb680094a0c173e8e5627ccc99543abded97204
# done
#   Stored in directory: /root/.cache/pip/wheels/89/77/ec/a537585d1022dafde0317dd19d33c4a30d4ee61e19f25ebd8e
# done
#   Stored in directory: /root/.cache/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
# done
#   Stored in directory: /root/.cache/pip/wheels/bc/86/aa/7680e54728998edc1e966a20249b920e582012ed6bdd3815c4
# Successfully built fastai bcolz feather-format torchtext pyproj munch click-plugins
# plotnine 0.4.0 has requirement scipy>=1.0.0, but you'll have scipy 0.19.1 which is incompatible.
# torchvision 0.2.1 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: bcolz, pyarrow, feather-format, graphviz, widgetsnbextension, ipywidgets, isoweek, parso, jedi, qtconsole, jupyter-console, jupyter, pandas-summary, shapely, pyproj, click, cligj, munch, click-plugins, fiona, geopandas, descartes, palettable, mizani, plotnine, sklearn-pandas, torch, torchtext, torchvision, fastai
# Successfully installed bcolz-1.2.1 click-6.7 click-plugins-1.0.3 cligj-0.4.0 descartes-1.1.0 fastai-0.7.0 feather-format-0.4.0 fiona-1.7.13 geopandas-0.4.0 graphviz-0.9 ipywidgets-7.4.1 isoweek-1.3.3 jedi-0.12.1 jupyter-1.0.0 jupyter-console-5.2.0 mizani-0.4.6 munch-2.3.2 palettable-3.1.1 pandas-summary-0.0.5 parso-0.3.1 plotnine-0.4.0 pyarrow-0.10.0 pyproj-1.9.5.1 qtconsole-4.4.1 shapely-1.6.4.post2 sklearn-pandas-1.7.0 torch-0.3.1 torchtext-0.2.3 torchvision-0.2.1 widgetsnbextension-3.4.1

# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# !pip3 install ipywidgets==6.0.0
# Out:
# Collecting ipywidgets==6.0.0
#   Downloading https://files.pythonhosted.org/packages/3b/52/3706ce0e828d65b29f00e9c8a340317fdb94d125afe322f807e98579bcbe/ipywidgets-6.0.0-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 3.7MB/s
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.3.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.6.1)
# Collecting widgetsnbextension~=2.0.0 (from ipywidgets==6.0.0)
#   Downloading https://files.pythonhosted.org/packages/50/b3/7c86d28eab49808e82f26ba9882ff31170e25b584f28edec80d6fdfc270c/widgetsnbextension-2.0.1-py2.py3-none-any.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 9.3MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0) (4.3.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0) (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0) (1.11.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (0.7.4)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (4.6.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (2.1.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (39.1.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (1.0.15)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0) (2.6.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0) (4.5.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (5.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0->ipywidgets==6.0.0) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets==6.0.0) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0) (2.5.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0) (16.0.4)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (5.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (2.10)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.8.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.4.2)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.3.1)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.8.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.2.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (2.1.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.0)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.5.1)
# Installing collected packages: widgetsnbextension, ipywidgets
#   Found existing installation: widgetsnbextension 3.4.1
#     Uninstalling widgetsnbextension-3.4.1:
#       Successfully uninstalled widgetsnbextension-3.4.1
#   Found existing installation: ipywidgets 7.4.1
#     Uninstalling ipywidgets-7.4.1:
#       Successfully uninstalled ipywidgets-7.4.1
# Successfully installed ipywidgets-6.0.0 widgetsnbextension-2.0.1

# %%
os.chdir('/content/fastai')
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: bcolz>=1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: bleach>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: certifi>=2016.2.28 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (2018.8.24)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: decorator>=4.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: entrypoints>=0.2.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: graphviz>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (0.9)
# Requirement already satisfied: html5lib>=0.999999999 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: ipykernel>=4.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (4.6.1)
# Collecting ipython>=6.2.0 (from -r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/f7/62/2fef7db3a7b75e8099c3d9db2630ae5ba0b9eefefd91f7497862393d90e8/ipython-6.5.0-py3-none-any.whl (748kB)
#     100% |████████████████████████████████| 757kB 9.5MB/s
# Requirement already satisfied: ipython-genutils>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (0.2.0)
# Collecting ipywidgets>=7.0.1 (from -r requirements.txt (line 12))
#   Using cached https://files.pythonhosted.org/packages/ea/c5/0482342559f0fd24909572fe00bb59b2bae98b22d90aac7950f51a98f555/ipywidgets-7.4.1-py2.py3-none-any.whl
# Requirement already satisfied: isoweek>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: jedi>=0.10.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: Jinja2>=2.9.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 15)) (2.10)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 16)) (2.6.0)
# Requirement already satisfied: jupyter>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: jupyter-client>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 18)) (5.2.3)
# Requirement already satisfied: jupyter-console>=5.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 19)) (5.2.0)
# Requirement already satisfied: jupyter-core>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 20)) (4.4.0)
# Requirement already satisfied: MarkupSafe>=1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 21)) (1.0)
# Requirement already satisfied: matplotlib>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 22)) (2.1.2)
# Requirement already satisfied: mistune>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 23)) (0.8.3)
# Requirement already satisfied: nbconvert>=5.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 24)) (5.4.0)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 25)) (4.4.0)
# Requirement already satisfied: notebook>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 26)) (5.2.2)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 27)) (1.14.5)
# Requirement already satisfied: olefile>=0.44 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 28)) (0.46)
# Requirement already satisfied: opencv-python>=3.3.0.10 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 29)) (3.4.3.18)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 30)) (0.22.0)
# Requirement already satisfied: pandas_summary>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 31)) (0.0.5)
# Requirement already satisfied: pandocfilters>=1.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 32)) (1.4.2)
# Requirement already satisfied: pexpect>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 33)) (4.6.0)
# Requirement already satisfied: pickleshare>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 34)) (0.7.4)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 35)) (5.2.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 36)) (1.0.15)
# Requirement already satisfied: ptyprocess>=0.5.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 37)) (0.6.0)
# Collecting Pygments>=2.2.0 (from -r requirements.txt (line 38))
#   Downloading https://files.pythonhosted.org/packages/02/ee/b6e02dc6529e82b75bb06823ff7d005b141037cb1416b10c6f00fc419dca/Pygments-2.2.0-py2.py3-none-any.whl (841kB)
#     100% |████████████████████████████████| 849kB 12.8MB/s
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 39)) (2.2.0)
# Collecting pytest>=3.5.0 (from -r requirements.txt (line 40))
#   Downloading https://files.pythonhosted.org/packages/dd/e5/1ce7de3e87ec499a056800fa0d7a689d6502d791c44eb1315a6ecadcb333/pytest-3.8.0-py2.py3-none-any.whl (208kB)
#     100% |████████████████████████████████| 215kB 11.4MB/s
# Collecting pytest-cov>=2.5.1 (from -r requirements.txt (line 41))
#   Downloading https://files.pythonhosted.org/packages/30/0a/1b009b525526cd3cd9f52f52391b426c5a3597447be811a10bcb1f6b05eb/pytest_cov-2.6.0-py2.py3-none-any.whl
# Collecting python-dateutil>=2.6.1 (from -r requirements.txt (line 42))
#   Downloading https://files.pythonhosted.org/packages/cf/f5/af2b09c957ace60dcfac112b669c45c8c97e32f94aa8b56da4c6d1682825/python_dateutil-2.7.3-py2.py3-none-any.whl (211kB)
#     100% |████████████████████████████████| 215kB 15.0MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 43)) (2018.5)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 44)) (3.13)
# Requirement already satisfied: pyzmq>=16.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 45)) (16.0.4)
# Requirement already satisfied: qtconsole>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 46)) (4.4.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 47)) (0.19.1)
# Collecting seaborn>=0.8.1 (from -r requirements.txt (line 48))
#   Downloading https://files.pythonhosted.org/packages/a8/76/220ba4420459d9c4c9c9587c6ce607bf56c25b3d3d2de62056efe482dadc/seaborn-0.9.0-py3-none-any.whl (208kB)
#     100% |████████████████████████████████| 215kB 14.4MB/s
# Requirement already satisfied: simplegeneric>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 49)) (0.8.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 50)) (1.11.0)
# Requirement already satisfied: sklearn_pandas>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 51)) (1.7.0)
# Requirement already satisfied: terminado>=0.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 52)) (0.8.1)
# Requirement already satisfied: testpath>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 53)) (0.3.1)
# Requirement already satisfied: torch<0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 54)) (0.3.0.post4)
# Requirement already satisfied: torchtext>=0.2.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 55)) (0.2.3)
# Requirement already satisfied: torchvision>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 56)) (0.2.1)
# Requirement already satisfied: tornado<5,>=4.5.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 57)) (4.5.3)
# Requirement already satisfied: tqdm>=4.15.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 58)) (4.25.0)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 59)) (4.3.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 60)) (0.1.7)
# Requirement already satisfied: webencodings>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 61)) (0.5.1)
# Collecting widgetsnbextension>=3.0.3 (from -r requirements.txt (line 62))
#   Using cached https://files.pythonhosted.org/packages/3c/9a/9a690e18e335fc4470a2fa38163774940159375798ba6cce043d5cd94bae/widgetsnbextension-3.4.1-py2.py3-none-any.whl
# Requirement already satisfied: spacy>=2.0.11 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 63)) (2.0.12)
# Collecting testfixtures>=6.2.0 (from -r requirements.txt (line 64))
#   Downloading https://files.pythonhosted.org/packages/5f/9a/6892c2f846cf7d750b1387a60b2f4e82a16581f0de2d0f942b6db3777ec4/testfixtures-6.3.0-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 24.8MB/s
# Collecting backcall (from ipython>=6.2.0->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=6.2.0->-r requirements.txt (line 10)) (39.1.0)
# Requirement already satisfied: parso>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10.2->-r requirements.txt (line 14)) (0.3.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert>=5.3.1->-r requirements.txt (line 24)) (0.5.0)
# Collecting atomicwrites>=1.0 (from pytest>=3.5.0->-r requirements.txt (line 40))
#   Downloading https://files.pythonhosted.org/packages/3a/9a/9d878f8d885706e2530402de6417141129a943802c084238914fa6798d97/atomicwrites-1.2.1-py2.py3-none-any.whl
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=3.5.0->-r requirements.txt (line 40)) (1.6.0)
# Requirement already satisfied: pluggy>=0.7 in /usr/local/lib/python3.6/dist-packages (from pytest>=3.5.0->-r requirements.txt (line 40)) (0.7.1)
# Collecting more-itertools>=4.0.0 (from pytest>=3.5.0->-r requirements.txt (line 40))
#   Downloading https://files.pythonhosted.org/packages/79/b1/eace304ef66bd7d3d8b2f78cc374b73ca03bc53664d78151e9df3b3996cc/more_itertools-4.3.0-py3-none-any.whl (48kB)
#     100% |████████████████████████████████| 51kB 20.0MB/s
# Collecting attrs>=17.4.0 (from pytest>=3.5.0->-r requirements.txt (line 40))
#   Downloading https://files.pythonhosted.org/packages/3a/e1/5f9023cc983f1a628a8c2fd051ad19e76ff7b142a0faf329336f9a62a514/attrs-18.2.0-py2.py3-none-any.whl
# Collecting coverage>=4.4 (from pytest-cov>=2.5.1->-r requirements.txt (line 41))
#   Downloading https://files.pythonhosted.org/packages/3d/a0/b12090c40e0b8196b973962ec71c1c541a6c04af58ba5ad85683b3de251a/coverage-4.5.1-cp36-cp36m-manylinux1_x86_64.whl (202kB)
#     100% |████████████████████████████████| 204kB 15.2MB/s
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_pandas>=1.6.0->-r requirements.txt (line 51)) (0.19.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext>=0.2.3->-r requirements.txt (line 55)) (2.18.4)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (0.28.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (1.0.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (6.10.3)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (0.9.6)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (1.35)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (0.2.8.2)
# Requirement already satisfied: regex==2017.4.5 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.11->-r requirements.txt (line 63)) (2017.4.5)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext>=0.2.3->-r requirements.txt (line 55)) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext>=0.2.3->-r requirements.txt (line 55)) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext>=0.2.3->-r requirements.txt (line 55)) (1.22)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy>=2.0.11->-r requirements.txt (line 63)) (0.5.6)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy>=2.0.11->-r requirements.txt (line 63)) (0.4.3.1)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy>=2.0.11->-r requirements.txt (line 63)) (0.9.0.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.11.0,>=6.10.3->spacy>=2.0.11->-r requirements.txt (line 63)) (1.10.11)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy>=2.0.11->-r requirements.txt (line 63)) (0.9.0)
# Building wheels for collected packages: backcall
# done
#   Stored in directory: /root/.cache/pip/wheels/98/b0/dd/29e28ff615af3dda4c67cab719dd51357597eabff926976b45
# Successfully built backcall
# Installing collected packages: backcall, Pygments, ipython, widgetsnbextension, ipywidgets, atomicwrites, more-itertools, attrs, pytest, coverage, pytest-cov, python-dateutil, seaborn, testfixtures
#   Found existing installation: Pygments 2.1.3
#     Uninstalling Pygments-2.1.3:
#       Successfully uninstalled Pygments-2.1.3
#   Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Found existing installation: widgetsnbextension 2.0.1
#     Uninstalling widgetsnbextension-2.0.1:
#       Successfully uninstalled widgetsnbextension-2.0.1
#   Found existing installation: ipywidgets 6.0.0
#     Uninstalling ipywidgets-6.0.0:
#       Successfully uninstalled ipywidgets-6.0.0
#   Found existing installation: python-dateutil 2.5.3
#     Uninstalling python-dateutil-2.5.3:
#       Successfully uninstalled python-dateutil-2.5.3
#   Found existing installation: seaborn 0.7.1
#     Uninstalling seaborn-0.7.1:
#       Successfully uninstalled seaborn-0.7.1
# Successfully installed Pygments-2.2.0 atomicwrites-1.2.1 attrs-18.2.0 backcall-0.1.0 coverage-4.5.1 ipython-6.5.0 ipywidgets-7.4.1 more-itertools-4.3.0 pytest-3.8.0 pytest-cov-2.6.0 python-dateutil-2.7.3 seaborn-0.9.0 testfixtures-6.3.0 widgetsnbextension-3.4.1

# %%
# !pip3 install -U scipy
# !python3 setup.py install
# Out:
# Collecting scipy
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#     100% |████████████████████████████████| 31.2MB 1.3MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy) (1.14.5)
# Installing collected packages: scipy
#   Found existing installation: scipy 0.19.1
#     Uninstalling scipy-0.19.1:
#       Successfully uninstalled scipy-0.19.1
# Successfully installed scipy-1.1.0
# running install
# running bdist_egg
# running egg_info
# creating fastai.egg-info
# writing fastai.egg-info/PKG-INFO
# writing dependency_links to fastai.egg-info/dependency_links.txt
# writing requirements to fastai.egg-info/requires.txt
# writing top-level names to fastai.egg-info/top_level.txt
# writing manifest file 'fastai.egg-info/SOURCES.txt'
# package init file 'fastai/models/__init__.py' not found (or not a regular file)
# package init file 'fastai/models/cifar10/__init__.py' not found (or not a regular file)
# reading manifest file 'fastai.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'Makefile'
# writing manifest file 'fastai.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/fastai
# copying fastai/executors.py -> build/lib/fastai
# copying fastai/lm_rnn.py -> build/lib/fastai
# copying fastai/learner.py -> build/lib/fastai
# copying fastai/swa.py -> build/lib/fastai
# copying fastai/core.py -> build/lib/fastai
# copying fastai/dataset.py -> build/lib/fastai
# copying fastai/transforms_pil.py -> build/lib/fastai
# copying fastai/dataloader.py -> build/lib/fastai
# copying fastai/plots.py -> build/lib/fastai
# copying fastai/model.py -> build/lib/fastai
# copying fastai/io.py -> build/lib/fastai
# copying fastai/__init__.py -> build/lib/fastai
# copying fastai/set_spawn.py -> build/lib/fastai
# copying fastai/lsuv_initializer.py -> build/lib/fastai
# copying fastai/fp16.py -> build/lib/fastai
# copying fastai/nlp.py -> build/lib/fastai
# copying fastai/layers.py -> build/lib/fastai
# copying fastai/adaptive_softmax.py -> build/lib/fastai
# copying fastai/layer_optimizer.py -> build/lib/fastai
# copying fastai/initializers.py -> build/lib/fastai
# copying fastai/text.py -> build/lib/fastai
# copying fastai/column_data.py -> build/lib/fastai
# copying fastai/structured.py -> build/lib/fastai
# copying fastai/transforms.py -> build/lib/fastai
# copying fastai/conv_learner.py -> build/lib/fastai
# copying fastai/rnn_reg.py -> build/lib/fastai
# copying fastai/sgdr.py -> build/lib/fastai
# copying fastai/rnn_train.py -> build/lib/fastai
# copying fastai/torch_imports.py -> build/lib/fastai
# copying fastai/metrics.py -> build/lib/fastai
# copying fastai/imports.py -> build/lib/fastai
# creating build/lib/fastai/models
# copying fastai/models/resnet.py -> build/lib/fastai/models
# copying fastai/models/wrn_50_2f.py -> build/lib/fastai/models
# copying fastai/models/wideresnet.py -> build/lib/fastai/models
# copying fastai/models/unet.py -> build/lib/fastai/models
# copying fastai/models/inceptionresnetv2.py -> build/lib/fastai/models
# copying fastai/models/fa_resnet.py -> build/lib/fastai/models
# copying fastai/models/resnext_50_32x4d.py -> build/lib/fastai/models
# copying fastai/models/nasnet.py -> build/lib/fastai/models
# copying fastai/models/resnext_101_64x4d.py -> build/lib/fastai/models
# copying fastai/models/senet.py -> build/lib/fastai/models
# copying fastai/models/convert_torch.py -> build/lib/fastai/models
# copying fastai/models/darknet.py -> build/lib/fastai/models
# copying fastai/models/resnext_101_32x4d.py -> build/lib/fastai/models
# copying fastai/models/inceptionv4.py -> build/lib/fastai/models
# creating build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/preact_resnet.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/wideresnet.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/utils_kuangliu.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/utils.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/senet.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/main_dxy.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/main_kuangliu.py -> build/lib/fastai/models/cifar10
# copying fastai/models/cifar10/resnext.py -> build/lib/fastai/models/cifar10
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/executors.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/lm_rnn.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/learner.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/swa.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/core.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/dataset.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/transforms_pil.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/dataloader.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/plots.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/model.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/io.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/__init__.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/set_spawn.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/lsuv_initializer.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/fp16.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/nlp.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/layers.py -> build/bdist.linux-x86_64/egg/fastai
# creating build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/resnet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/wrn_50_2f.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/wideresnet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/unet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/inceptionresnetv2.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/fa_resnet.py -> build/bdist.linux-x86_64/egg/fastai/models
# creating build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/preact_resnet.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/wideresnet.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/utils_kuangliu.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/utils.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/senet.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/main_dxy.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/main_kuangliu.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/cifar10/resnext.py -> build/bdist.linux-x86_64/egg/fastai/models/cifar10
# copying build/lib/fastai/models/resnext_50_32x4d.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/nasnet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/resnext_101_64x4d.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/senet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/convert_torch.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/darknet.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/resnext_101_32x4d.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/models/inceptionv4.py -> build/bdist.linux-x86_64/egg/fastai/models
# copying build/lib/fastai/adaptive_softmax.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/layer_optimizer.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/initializers.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/text.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/column_data.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/structured.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/transforms.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/conv_learner.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/rnn_reg.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/sgdr.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/rnn_train.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/torch_imports.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/metrics.py -> build/bdist.linux-x86_64/egg/fastai
# copying build/lib/fastai/imports.py -> build/bdist.linux-x86_64/egg/fastai
# byte-compiling build/bdist.linux-x86_64/egg/fastai/executors.py to executors.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/lm_rnn.py to lm_rnn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/learner.py to learner.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/swa.py to swa.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/core.py to core.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/dataset.py to dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/transforms_pil.py to transforms_pil.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/dataloader.py to dataloader.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/plots.py to plots.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/model.py to model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/io.py to io.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/set_spawn.py to set_spawn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/lsuv_initializer.py to lsuv_initializer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/fp16.py to fp16.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/nlp.py to nlp.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/layers.py to layers.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/resnet.py to resnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/wrn_50_2f.py to wrn_50_2f.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/wideresnet.py to wideresnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/unet.py to unet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/inceptionresnetv2.py to inceptionresnetv2.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/fa_resnet.py to fa_resnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/preact_resnet.py to preact_resnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/wideresnet.py to wideresnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/utils_kuangliu.py to utils_kuangliu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/utils.py to utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/senet.py to senet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/main_dxy.py to main_dxy.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/main_kuangliu.py to main_kuangliu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/cifar10/resnext.py to resnext.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/resnext_50_32x4d.py to resnext_50_32x4d.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/nasnet.py to nasnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/resnext_101_64x4d.py to resnext_101_64x4d.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/senet.py to senet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/convert_torch.py to convert_torch.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/darknet.py to darknet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/resnext_101_32x4d.py to resnext_101_32x4d.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/models/inceptionv4.py to inceptionv4.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/adaptive_softmax.py to adaptive_softmax.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/layer_optimizer.py to layer_optimizer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/initializers.py to initializers.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/text.py to text.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/column_data.py to column_data.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/structured.py to structured.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/transforms.py to transforms.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/conv_learner.py to conv_learner.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/rnn_reg.py to rnn_reg.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/sgdr.py to sgdr.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/rnn_train.py to rnn_train.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/torch_imports.py to torch_imports.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/metrics.py to metrics.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fastai/imports.py to imports.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying fastai.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fastai.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fastai.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fastai.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fastai.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# fastai.__pycache__.torch_imports.cpython-36: module references __file__
# creating dist
# creating 'dist/fastai-0.7.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing fastai-0.7.0-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/fastai-0.7.0-py3.6.egg
# Extracting fastai-0.7.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding fastai 0.7.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/fastai-0.7.0-py3.6.egg
# Processing dependencies for fastai==0.7.0
# Searching for widgetsnbextension==3.4.1
# Best match: widgetsnbextension 3.4.1
# Adding widgetsnbextension 3.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Adding webencodings 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wcwidth==0.1.7
# Best match: wcwidth 0.1.7
# Adding wcwidth 0.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for traitlets==4.3.2
# Best match: traitlets 4.3.2
# Adding traitlets 4.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tqdm==4.25.0
# Best match: tqdm 4.25.0
# Adding tqdm 4.25.0 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tornado==4.5.3
# Best match: tornado 4.5.3
# Adding tornado 4.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for torchvision==0.2.1
# Best match: torchvision 0.2.1
# Adding torchvision 0.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for torchtext==0.2.3
# Best match: torchtext 0.2.3
# Adding torchtext 0.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for torch==0.3.0.post4
# Best match: torch 0.3.0.post4
# Adding torch 0.3.0.post4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for testpath==0.3.1
# Best match: testpath 0.3.1
# Adding testpath 0.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for spacy==2.0.12
# Best match: spacy 2.0.12
# Adding spacy 2.0.12 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for sklearn-pandas==1.7.0
# Best match: sklearn-pandas 1.7.0
# Adding sklearn-pandas 1.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for simplegeneric==0.8.1
# Best match: simplegeneric 0.8.1
# Adding simplegeneric 0.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for seaborn==0.9.0
# Best match: seaborn 0.9.0
# Adding seaborn 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scipy==1.1.0
# Best match: scipy 1.1.0
# Adding scipy 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyzmq==16.0.4
# Best match: pyzmq 16.0.4
# Adding pyzmq 16.0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.5
# Best match: pytz 2018.5
# Adding pytz 2018.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.7.3
# Best match: python-dateutil 2.7.3
# Adding python-dateutil 2.7.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyparsing==2.2.0
# Best match: pyparsing 2.2.0
# Adding pyparsing 2.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pygments==2.2.0
# Best match: Pygments 2.2.0
# Adding Pygments 2.2.0 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ptyprocess==0.6.0
# Best match: ptyprocess 0.6.0
# Adding ptyprocess 0.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for plotnine==0.4.0
# Best match: plotnine 0.4.0
# Adding plotnine 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pillow==5.2.0
# Best match: Pillow 5.2.0
# Adding Pillow 5.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pickleshare==0.7.4
# Best match: pickleshare 0.7.4
# Adding pickleshare 0.7.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pandas-summary==0.0.5
# Best match: pandas-summary 0.0.5
# Adding pandas-summary 0.0.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pandas==0.22.0
# Best match: pandas 0.22.0
# Adding pandas 0.22.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for opencv-python==3.4.3.18
# Best match: opencv-python 3.4.3.18
# Adding opencv-python 3.4.3.18 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.14.5
# Best match: numpy 1.14.5
# Adding numpy 1.14.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for matplotlib==2.1.2
# Best match: matplotlib 2.1.2
# Adding matplotlib 2.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for MarkupSafe==1.0
# Best match: MarkupSafe 1.0
# Adding MarkupSafe 1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jupyter==1.0.0
# Best match: jupyter 1.0.0
# Adding jupyter 1.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jsonschema==2.6.0
# Best match: jsonschema 2.6.0
# Adding jsonschema 2.6.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.10
# Best match: Jinja2 2.10
# Adding Jinja2 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jedi==0.12.1
# Best match: jedi 0.12.1
# Adding jedi 0.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for isoweek==1.3.3
# Best match: isoweek 1.3.3
# Adding isoweek 1.3.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ipywidgets==7.4.1
# Best match: ipywidgets 7.4.1
# Adding ipywidgets 7.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Adding ipython-genutils 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ipython==6.5.0
# Best match: ipython 6.5.0
# Adding ipython 6.5.0 to easy-install.pth file
# Installing iptest script to /usr/local/bin
# Installing iptest3 script to /usr/local/bin
# Installing ipython script to /usr/local/bin
# Installing ipython3 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ipykernel==4.6.1
# Best match: ipykernel 4.6.1
# Adding ipykernel 4.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for html5lib==1.0.1
# Best match: html5lib 1.0.1
# Adding html5lib 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for graphviz==0.9
# Best match: graphviz 0.9
# Adding graphviz 0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for feather-format==0.4.0
# Best match: feather-format 0.4.0
# Adding feather-format 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for entrypoints==0.2.3
# Best match: entrypoints 0.2.3
# Adding entrypoints 0.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for decorator==4.3.0
# Best match: decorator 4.3.0
# Adding decorator 4.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2018.8.24
# Best match: certifi 2018.8.24
# Adding certifi 2018.8.24 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for bleach==2.1.4
# Best match: bleach 2.1.4
# Adding bleach 2.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for bcolz==1.2.1
# Best match: bcolz 1.2.1
# Adding bcolz 1.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for notebook==5.2.2
# Best match: notebook 5.2.2
# Adding notebook 5.2.2 to easy-install.pth file
# Installing jupyter-bundlerextension script to /usr/local/bin
# Installing jupyter-nbextension script to /usr/local/bin
# Installing jupyter-notebook script to /usr/local/bin
# Installing jupyter-serverextension script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.11.0
# Best match: six 1.11.0
# Adding six 1.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests==2.18.4
# Best match: requests 2.18.4
# Adding requests 2.18.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for regex==2017.4.5
# Best match: regex 2017.4.5
# Adding regex 2017.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for dill==0.2.8.2
# Best match: dill 0.2.8.2
# Adding dill 0.2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for ujson==1.35
# Best match: ujson 1.35
# Adding ujson 1.35 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for plac==0.9.6
# Best match: plac 0.9.6
# Adding plac 0.9.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for thinc==6.10.3
# Best match: thinc 6.10.3
# Adding thinc 6.10.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for preshed==1.0.1
# Best match: preshed 1.0.1
# Adding preshed 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cymem==1.31.2
# Best match: cymem 1.31.2
# Adding cymem 1.31.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for murmurhash==0.28.0
# Best match: murmurhash 0.28.0
# Adding murmurhash 0.28.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scikit-learn==0.19.2
# Best match: scikit-learn 0.19.2
# Adding scikit-learn 0.19.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for mizani==0.4.6
# Best match: mizani 0.4.6
# Adding mizani 0.4.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for descartes==1.1.0
# Best match: descartes 1.1.0
# Adding descartes 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for geopandas==0.4.0
# Best match: geopandas 0.4.0
# Adding geopandas 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for statsmodels==0.8.0
# Best match: statsmodels 0.8.0
# Adding statsmodels 0.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for patsy==0.5.0
# Best match: patsy 0.5.0
# Adding patsy 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for nbconvert==5.4.0
# Best match: nbconvert 5.4.0
# Adding nbconvert 5.4.0 to easy-install.pth file
# Installing jupyter-nbconvert script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for qtconsole==4.4.1
# Best match: qtconsole 4.4.1
# Adding qtconsole 4.4.1 to easy-install.pth file
# Installing jupyter-qtconsole script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jupyter-console==5.2.0
# Best match: jupyter-console 5.2.0
# Adding jupyter-console 5.2.0 to easy-install.pth file
# Installing jupyter-console script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for parso==0.3.1
# Best match: parso 0.3.1
# Adding parso 0.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for nbformat==4.4.0
# Best match: nbformat 4.4.0
# Adding nbformat 4.4.0 to easy-install.pth file
# Installing jupyter-trust script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for backcall==0.1.0
# Best match: backcall 0.1.0
# Adding backcall 0.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pexpect==4.6.0
# Best match: pexpect 4.6.0
# Adding pexpect 4.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for prompt-toolkit==1.0.15
# Best match: prompt-toolkit 1.0.15
# Adding prompt-toolkit 1.0.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==39.1.0
# Best match: setuptools 39.1.0
# Adding setuptools 39.1.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jupyter-client==5.2.3
# Best match: jupyter-client 5.2.3
# Adding jupyter-client 5.2.3 to easy-install.pth file
# Installing jupyter-kernel script to /usr/local/bin
# Installing jupyter-kernelspec script to /usr/local/bin
# Installing jupyter-run script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyarrow==0.10.0
# Best match: pyarrow 0.10.0
# Adding pyarrow 0.10.0 to easy-install.pth file
# Installing plasma_store script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jupyter-core==4.4.0
# Best match: jupyter-core 4.4.0
# Adding jupyter-core 4.4.0 to easy-install.pth file
# Installing jupyter script to /usr/local/bin
# Installing jupyter-migrate script to /usr/local/bin
# Installing jupyter-troubleshoot script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for terminado==0.8.1
# Best match: terminado 0.8.1
# Adding terminado 0.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.6
# Best match: idna 2.6
# Adding idna 2.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.22
# Best match: urllib3 1.22
# Adding urllib3 1.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wrapt==1.10.11
# Best match: wrapt 1.10.11
# Adding wrapt 1.10.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cytoolz==0.9.0.1
# Best match: cytoolz 0.9.0.1
# Adding cytoolz 0.9.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for msgpack-numpy==0.4.3.1
# Best match: msgpack-numpy 0.4.3.1
# Adding msgpack-numpy 0.4.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for msgpack==0.5.6
# Best match: msgpack 0.5.6
# Adding msgpack 0.5.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for palettable==3.1.1
# Best match: palettable 3.1.1
# Adding palettable 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyproj==1.9.5.1
# Best match: pyproj 1.9.5.1
# Adding pyproj 1.9.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Fiona==1.7.13
# Best match: Fiona 1.7.13
# Adding Fiona 1.7.13 to easy-install.pth file
# Installing fio script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Shapely==1.6.4.post2
# Best match: Shapely 1.6.4.post2
# Adding Shapely 1.6.4.post2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for mistune==0.8.3
# Best match: mistune 0.8.3
# Adding mistune 0.8.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for defusedxml==0.5.0
# Best match: defusedxml 0.5.0
# Adding defusedxml 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pandocfilters==1.4.2
# Best match: pandocfilters 1.4.2
# Adding pandocfilters 1.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for toolz==0.9.0
# Best match: toolz 0.9.0
# Adding toolz 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cligj==0.4.0
# Best match: cligj 0.4.0
# Adding cligj 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for munch==2.3.2
# Best match: munch 2.3.2
# Adding munch 2.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for click-plugins==1.0.3
# Best match: click-plugins 1.0.3
# Adding click-plugins 1.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for click==6.7
# Best match: click 6.7
# Adding click 6.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for fastai==0.7.0

# %%
# !cd /content
# !mkdir data
# Out:
# /bin/bash: line 0: cd: /content/data: No such file or directory
